# %%
from Environment import Environment
from Agents import DQNAgent
from Engine import Engine
# Out:
# 2023-11-08 13:30:24.797825: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-08 13:30:24.848250: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-08 13:30:24.848297: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-08 13:30:24.848348: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-08 13:30:24.857912: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
size = (8,8)
goal_reward  = 100
fail_penalty = -10
time_penalty = -1
outOfBoundsList = [(x,1) for x in range(3)]
for i in range(4):
    outOfBoundsList += [(x,5-i) for x in range(4+i,8)]
for i in range(3):
    outOfBoundsList += [(x,7-i) for x in range(3-i)]
goalList = [(7,6)]

state_dim = 4
action_dim = 9

gamma = .9

env = Environment(size,goal_reward,fail_penalty,time_penalty,outOfBoundsList,goalList)
agent = DQNAgent(state_dim,action_dim, gamma = gamma)
engine = Engine(env,agent)

env.display()

# %% [markdown]
# metrics = engine.train(epsilon=.5, limit = 20, batch_size = 100, trials = 10)

# %% [markdown]
# metrics_vec = engine.train_vec(batch_size=100,trials=10,epsilon=.5)

# %%
metrics1 = engine.train_dynamic(10000)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig,ax = plt.subplots(2,1,figsize=(10,10))
df = pd.DataFrame(metrics1)
df["loss"].plot(ax=ax[0])
ax[0].set_title("MSE Loss")
ax[0].set_ylabel("MSE Loss")
df[["Q_model","Q_update"]].plot(ax=ax[1])
ax[1].set_title("Average Q-val")
ax[1].set_ylabel("Average Q-val")
# Out:
# Text(0, 0.5, 'Average Q-val')

# %%
import numpy as np
engine.Agent.model(np.array([[6,6,0,0]]))
# Out:
# <tf.Tensor: shape=(1, 9), dtype=float32, numpy=
# array([[ 86.382355,  81.44513 ,  62.75941 ,  78.95163 ,   8.560854,
#          75.74023 ,  -9.447141, -15.886534, -14.184439]], dtype=float32)>

# %%
engine.display_run((6,6,0,0),epsilon=0);
# Out:
# ...
# 1/1 [==============================] - 0s 35ms/step

# %%
metrics2 = engine.train_dynamic(10000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 metrics2 = engine.train_dynamic(10000)
#
# File ~/Projects/NeuralNetQLearning/DQN/Engine.py:201, in Engine.train_dynamic(self, trials)
#     199 for t in range(trials):
#     200     np.random.shuffle(index)
# --> 201     loss,Q_model,Q_update = self.Agent.update_all(states[index], next_states[index], rewards[index], terminal[index],MIN,MAX)
#     202     metrics['loss'].append(loss)
#     203     metrics['Q_model'].append(Q_model)
#
# File ~/Projects/NeuralNetQLearning/DQN/Agents.py:63, in DQNAgent.update_all(self, states, next_states, rewards, dones, MIN, MAX)
#      47 """
#      48 Update Actor and Critic Networks
#      49
#    (...)
#      60     A tuple: (actor_loss,critic_loss)
#      61 """
#      62 n = len(states)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig,ax = plt.subplots(2,1,figsize=(10,10))
df = pd.DataFrame(metrics2)
df["loss"].plot(ax=ax[0])
ax[0].set_title("MSE Loss")
ax[0].set_ylabel("MSE Loss")
df[["Q_model","Q_update"]].plot(ax=ax[1])
ax[1].set_title("Average Q-val")
ax[1].set_ylabel("Average Q-val")
# Out:
# Text(0, 0.5, 'Average Q-val')

# %%
import numpy as np
engine.Agent.model(np.array([[6,6,0,0]]))
# Out:
# <tf.Tensor: shape=(1, 9), dtype=float32, numpy=
# array([[ 90.20628 , 101.05267 ,  71.86499 ,  87.97635 ,  14.465688,
#          77.28162 ,  -8.509368, -11.880387,  -1.114738]], dtype=float32)>

# %%
engine.display_run((0,0,0,0),epsilon=0);
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
metrics3 = engine.train_dynamic(10000)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig,ax = plt.subplots(2,1,figsize=(10,10))
df = pd.DataFrame(metrics3)
df["loss"].plot(ax=ax[0])
ax[0].set_title("MSE Loss")
ax[0].set_ylabel("MSE Loss")
df[["Q_model","Q_update"]].plot(ax=ax[1])
ax[1].set_title("Average Q-val")
ax[1].set_ylabel("Average Q-val")

# %%
import numpy as np
engine.Agent.model(np.array([[6,6,0,0]]))

# %%
engine.display_run((0,0,0,0),epsilon=0);

# %%
metrics4 = engine.train_dynamic(10000)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig,ax = plt.subplots(2,1,figsize=(10,10))
df = pd.DataFrame(metrics4)
df["loss"].plot(ax=ax[0])
ax[0].set_title("MSE Loss")
ax[0].set_ylabel("MSE Loss")
df[["Q_model","Q_update"]].plot(ax=ax[1])
ax[1].set_title("Average Q-val")
ax[1].set_ylabel("Average Q-val")

# %%
import numpy as np
engine.Agent.model(np.array([[6,6,0,0]]))

# %%
engine.display_run((0,0,0,0),epsilon=0);
